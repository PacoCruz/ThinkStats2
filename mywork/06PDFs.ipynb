# %%
# ln -s ../code/analytic.py analytic.py
# %matplotlib inline

import numpy as np
import math

import nsfg
import first
import thinkstats2
import thinkplot
import density

# %%
mean, var = 163, 52.8
std = math.sqrt(var)
pdf = thinkstats2.NormalPdf(mean, std)
pdf.Density(mean + std)
# Out:
# 0.033300124989618714

# %%
thinkplot.Pdf(pdf=pdf, label='Normal')
thinkplot.Show()

# %%
sample = []
